# %%
import hisepy as hp

# %%
download = hp.cache_files(['b84fae76-4ff5-43b6-bd38-77c7eab6a036'])

# %%
download
# Out:
# ['/home/workspace/input/3974417942/fh1_treat/b84fae76-4ff5-43b6-bd38-77c7eab6a036/esOyYqxavR/final-pbmc-raw.h5ad']
