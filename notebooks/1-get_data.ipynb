# %%
import hisepy as hp

# %%
download = hp.cache_files(['00a37f08-b950-45d2-b505-48ba9cb91c01'])

# %%
download
# Out:
# ['/home/workspace/input/3974417942/FH_MM_Year4/00a37f08-b950-45d2-b505-48ba9cb91c01/1LOr4Ui1tr/final-bmmc-raw.h5ad']
